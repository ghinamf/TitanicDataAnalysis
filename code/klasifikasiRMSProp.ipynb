# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import RMSprop
import keras_tuner as kt

# %%
df = pd.read_csv("D:/TEL U/S2 TELU/SEM 2 TELU/MATLANJUT/CODE1/td.csv")

df.drop(['PassengerId', 'Name', 'Ticket', 'Cabin'], axis=1, inplace=True)
df['Age'].fillna(df['Age'].median(), inplace=True)
df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)

le = LabelEncoder()
df['Sex'] = le.fit_transform(df['Sex'])
df['Embarked'] = le.fit_transform(df['Embarked'])

X = df.drop('Survived', axis=1)
y = df['Survived']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_14732\174186719.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].median(), inplace=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_14732\174186719.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)

# %%
def build_model(hp):
    model = Sequential()
    model.add(Dense(
        units=hp.Choice('units_input', [32, 64, 128]),
        activation='relu',
        input_shape=(X_train.shape[1],)
    ))
    if hp.Boolean('use_hidden_layer'):
        model.add(Dense(
            units=hp.Choice('units_hidden', [32, 64, 128]),
            activation='relu'
        ))
    model.add(Dense(1, activation='sigmoid'))

    lr = hp.Choice('learning_rate', [1e-2, 1e-3, 1e-4])
    rho = hp.Choice('rho', [0.8, 0.9, 0.95])
    momentum = hp.Choice('momentum', [0.0, 0.8, 0.9])
    epsilon = 1e-7

    model.compile(
        optimizer=RMSprop(learning_rate=lr, rho=rho, momentum=momentum, epsilon=epsilon),
        loss='binary_crossentropy',
        metrics=['accuracy']
    )
    return model

# %%
tuner = kt.RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=20,
    directory='random_search_rmsprop',
    project_name='titanic_rmsprop'
)

# %%
tuner.search(X_train, y_train, epochs=30, validation_split=0.2, verbose=1)
# Out:
# Trial 20 Complete [00h 00m 06s]
# val_accuracy: 0.8601398468017578
#
# Best val_accuracy So Far: 0.8601398468017578
# Total elapsed time: 00h 02m 05s

# %%
best_hp = tuner.get_best_hyperparameters(1)[0]
model = tuner.hypermodel.build(best_hp)

history = model.fit(X_train, y_train, epochs=30, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.6927 - loss: 0.6886 - val_accuracy: 0.8322 - val_loss: 0.3939
# Epoch 2/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8192 - loss: 0.4267 - val_accuracy: 0.8462 - val_loss: 0.4106
# Epoch 3/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8442 - loss: 0.4324 - val_accuracy: 0.8112 - val_loss: 0.4017
# Epoch 4/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8049 - loss: 0.4196 - val_accuracy: 0.8112 - val_loss: 0.4063
# Epoch 5/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8036 - loss: 0.4382 - val_accuracy: 0.8042 - val_loss: 0.4016
# Epoch 6/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8073 - loss: 0.4511 - val_accuracy: 0.7972 - val_loss: 0.4426
# Epoch 7/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8151 - loss: 0.4386 - val_accuracy: 0.8322 - val_loss: 0.4290
# Epoch 8/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8148 - loss: 0.3974 - val_accuracy: 0.8322 - val_loss: 0.4730
# Epoch 9/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8422 - loss: 0.3886 - val_accuracy: 0.8462 - val_loss: 0.4309
# Epoch 10/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8292 - loss: 0.4431 - val_accuracy: 0.8462 - val_loss: 0.4097
# Epoch 11/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8231 - loss: 0.4110 - val_accuracy: 0.8042 - val_loss: 0.4213
# Epoch 12/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8279 - loss: 0.4042 - val_accuracy: 0.8252 - val_loss: 0.4059
# Epoch 13/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8310 - loss: 0.3877 - val_accuracy: 0.8462 - val_loss: 0.3915
# Epoch 14/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8329 - loss: 0.3962 - val_accuracy: 0.8112 - val_loss: 0.4174
# Epoch 15/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8389 - loss: 0.4196 - val_accuracy: 0.8112 - val_loss: 0.4177
# Epoch 16/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7881 - loss: 0.4346 - val_accuracy: 0.8112 - val_loss: 0.4244
# Epoch 17/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8125 - loss: 0.4112 - val_accuracy: 0.8112 - val_loss: 0.4103
# Epoch 18/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8407 - loss: 0.3607 - val_accuracy: 0.8182 - val_loss: 0.4149
# Epoch 19/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8564 - loss: 0.3392 - val_accuracy: 0.8042 - val_loss: 0.4389
# Epoch 20/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8265 - loss: 0.4091 - val_accuracy: 0.8392 - val_loss: 0.4242
# Epoch 21/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8442 - loss: 0.3751 - val_accuracy: 0.8182 - val_loss: 0.4327
# Epoch 22/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8185 - loss: 0.3811 - val_accuracy: 0.7972 - val_loss: 0.4344
# Epoch 23/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8282 - loss: 0.4156 - val_accuracy: 0.8322 - val_loss: 0.4834
# Epoch 24/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8184 - loss: 0.3819 - val_accuracy: 0.8112 - val_loss: 0.4090
# Epoch 25/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8339 - loss: 0.3695 - val_accuracy: 0.7902 - val_loss: 0.4866
# Epoch 26/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8346 - loss: 0.3682 - val_accuracy: 0.8042 - val_loss: 0.4903
# Epoch 27/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8501 - loss: 0.3537 - val_accuracy: 0.8392 - val_loss: 0.4581
# Epoch 28/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8732 - loss: 0.3352 - val_accuracy: 0.8042 - val_loss: 0.4826
# Epoch 29/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8280 - loss: 0.3547 - val_accuracy: 0.8322 - val_loss: 0.5064
# Epoch 30/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8555 - loss: 0.3425 - val_accuracy: 0.8392 - val_loss: 0.4842

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print(f"✅ Grid Search - Test Accuracy: {accuracy:.4f}")

y_pred_prob = model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)

print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8114 - loss: 0.6026
# ✅ Grid Search - Test Accuracy: 0.7989
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.80      0.88      0.84       105
#            1       0.80      0.69      0.74        74
#
#     accuracy                           0.80       179
#    macro avg       0.80      0.78      0.79       179
# weighted avg       0.80      0.80      0.80       179
#
# Confusion Matrix:
#  [[92 13]
#  [23 51]]

# %%
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
ConfusionMatrixDisplay.from_predictions(y_test, y_pred, cmap='Blues')
plt.title("Confusion Matrix")
plt.show()
